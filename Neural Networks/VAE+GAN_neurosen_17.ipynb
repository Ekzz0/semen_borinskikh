# %%
import numpy as np
import matplotlib.pyplot as plt
import time

from tensorflow.keras.datasets import mnist
from tensorflow import keras
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, Lambda, BatchNormalization, Dropout
from tensorflow.keras.layers import Conv2D, LeakyReLU

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train[y_train==7]
y_train = y_train[y_train==7]

BUFFER_SIZE = x_train.shape[0]
BATCH_SIZE = 100

length = BUFFER_SIZE // BATCH_SIZE * BATCH_SIZE
x_train = x_train[:length]
y_train = y_train[:length]
print(x_train.shape, y_train.shape)

# стандартизация входных данных
x_train = x_train / 255
x_test = x_test / 255

x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test  = np.reshape(x_test,  (len(x_test),  28, 28, 1))


train_dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
# Out:
# (6200, 28, 28) (6200,)

# %%
# формирование сетей
hidden_dim = 2

def dropout_and_batch(x):
    return Dropout(0.3)(BatchNormalization()(x))

input_img = Input((28, 28, 1))
x = Flatten()(input_img)
x = Dense(256, activation='relu')(x)
x = dropout_and_batch(x)

z_mean = Dense(hidden_dim)(x)
z_log_var = Dense(hidden_dim)(x)

def noiser(args):
    global z_mean, z_log_var
    z_mean, z_log_var = args
    N = K.random_normal(shape=(BATCH_SIZE, hidden_dim), mean=0., stddev=1.0)
    return K.exp(z_log_var / 2) * N + z_mean

h = Lambda(noiser, output_shape=(hidden_dim,))([z_mean, z_log_var])

input_dec = Input(shape=(hidden_dim,))
d = Dense(256, activation='relu')(input_dec)
d = dropout_and_batch(d)
d = Dense(28*28, activation='sigmoid')(d)
decoded = Reshape((28, 28, 1))(d)

encoder = keras.Model(input_img, h, name='encoder')
decoder = keras.Model(input_dec, decoded, name='decoder')
generator = keras.Model(input_img, decoder(encoder(input_img)), name="generator")

# дискриминатор
discriminator = tf.keras.Sequential()
discriminator.add(Conv2D(64, (5, 5), strides=(2, 2), padding='same', input_shape=[28, 28, 1]))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))

discriminator.add(Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))

discriminator.add(Flatten())
discriminator.add(Dense(1))

# %%
# потери
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def generator_loss(fake_output):
    loss = cross_entropy(tf.ones_like(fake_output), fake_output)
    kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return (loss + kl_loss*0.1)


def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
# обучение
@tf.function
def train_step(images):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(images, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss

# %%
def train(dataset, epochs):
    history = []
    MAX_PRINT_LABEL = 10
    th = BUFFER_SIZE // (BATCH_SIZE*MAX_PRINT_LABEL)

    n_epoch = 1
    for epoch in range(epochs):
        print(f'{n_epoch}/{EPOCHS}: ', end='')

        start = time.time()
        n = 0

        gen_loss_epoch = 0
        for image_batch in dataset:
            gen_loss, disc_loss = train_step(image_batch)
            gen_loss_epoch += K.mean(gen_loss)
            if( n % th == 0): print('=', end='')
            n += 1

        history += [gen_loss_epoch/n]
        print(': '+str(history[-1]))
        print ('Время эпохи {} в {} секундах'.format(epoch + 1, time.time()-start))

        n_epoch += 1
    return history

# %%
# запуск процесса обучения
EPOCHS = 50

history = train(train_dataset, EPOCHS)


h = encoder.predict(x_test[:6000], batch_size=BATCH_SIZE)
plt.scatter(h[:, 0], h[:, 1])

plt.plot(history)
plt.grid(True)
# Out:
# 1/50: ===========: tf.Tensor(2.648668, shape=(), dtype=float32)
# Время эпохи 1 в 12.482148170471191 секундах
# 2/50: ===========: tf.Tensor(6.343383, shape=(), dtype=float32)
# Время эпохи 2 в 11.900924921035767 секундах
# 3/50: ===========: tf.Tensor(11.118814, shape=(), dtype=float32)
# Время эпохи 3 в 12.114499568939209 секундах
# 4/50: ===========: tf.Tensor(17.682863, shape=(), dtype=float32)
# Время эпохи 4 в 11.514839172363281 секундах
# 5/50: ===========: tf.Tensor(23.2733, shape=(), dtype=float32)
# Время эпохи 5 в 11.841586112976074 секундах
# 6/50: ===========: tf.Tensor(24.297295, shape=(), dtype=float32)
# Время эпохи 6 в 12.593920707702637 секундах
# 7/50: ===========: tf.Tensor(21.533617, shape=(), dtype=float32)
# Время эпохи 7 в 11.26884651184082 секундах
# 8/50: ===========: tf.Tensor(18.326017, shape=(), dtype=float32)
# Время эпохи 8 в 10.165208101272583 секундах
# 9/50: ===========: tf.Tensor(16.639484, shape=(), dtype=float32)
# Время эпохи 9 в 10.219656467437744 секундах
# 10/50: ===========: tf.Tensor(16.243223, shape=(), dtype=float32)
# Время эпохи 10 в 10.363270998001099 секундах
# 11/50: ===========: tf.Tensor(16.593582, shape=(), dtype=float32)
# Время эпохи 11 в 10.901220560073853 секундах
# 12/50: ===========: tf.Tensor(17.51757, shape=(), dtype=float32)
# Время эпохи 12 в 11.21604871749878 секундах
# 13/50: ===========: tf.Tensor(15.409896, shape=(), dtype=float32)
# Время эпохи 13 в 10.326648473739624 секундах
# 14/50: ===========: tf.Tensor(13.812136, shape=(), dtype=float32)
# Время эпохи 14 в 10.62950873374939 секундах
# 15/50: ===========: tf.Tensor(12.774003, shape=(), dtype=float32)
# Время эпохи 15 в 10.868476152420044 секундах
# 16/50: ===========: tf.Tensor(11.481685, shape=(), dtype=float32)
# Время эпохи 16 в 11.575026035308838 секундах
# 17/50: ===========: tf.Tensor(10.463559, shape=(), dtype=float32)
# Время эпохи 17 в 10.685863494873047 секундах
# 18/50: ===========: tf.Tensor(10.387093, shape=(), dtype=float32)
# Время эпохи 18 в 10.736251831054688 секундах
# 19/50: ===========: tf.Tensor(9.897183, shape=(), dtype=float32)
# Время эпохи 19 в 10.562434434890747 секундах
# 20/50: ===========: tf.Tensor(10.184809, shape=(), dtype=float32)
# Время эпохи 20 в 11.082791805267334 секундах
# 21/50: ===========: tf.Tensor(9.228532, shape=(), dtype=float32)
# Время эпохи 21 в 11.164735794067383 секундах
# 22/50: ===========: tf.Tensor(8.572763, shape=(), dtype=float32)
# Время эпохи 22 в 10.574624300003052 секундах
# 23/50: ===========: tf.Tensor(8.467558, shape=(), dtype=float32)
# Время эпохи 23 в 10.68834114074707 секундах
# 24/50: ===========: tf.Tensor(7.9410887, shape=(), dtype=float32)
# Время эпохи 24 в 10.67020297050476 секундах
# 25/50: ===========: tf.Tensor(7.698182, shape=(), dtype=float32)
# Время эпохи 25 в 10.562323093414307 секундах
# 26/50: ===========: tf.Tensor(7.8768525, shape=(), dtype=float32)
# Время эпохи 26 в 10.4080491065979 секундах
# 27/50: ===========: tf.Tensor(7.73764, shape=(), dtype=float32)
# Время эпохи 27 в 10.75116491317749 секундах
# 28/50: ===========: tf.Tensor(7.0553975, shape=(), dtype=float32)
# Время эпохи 28 в 10.18146538734436 секундах
# 29/50: ===========: tf.Tensor(7.0320983, shape=(), dtype=float32)
# Время эпохи 29 в 11.14676833152771 секундах
# 30/50: ===========: tf.Tensor(6.7374115, shape=(), dtype=float32)
# Время эпохи 30 в 10.677904844284058 секундах
# 31/50: ===========: tf.Tensor(6.6181445, shape=(), dtype=float32)
# Время эпохи 31 в 11.844667434692383 секундах
# 32/50: ===========: tf.Tensor(6.5452647, shape=(), dtype=float32)
# Время эпохи 32 в 12.089258432388306 секундах
# 33/50: ===========: tf.Tensor(6.1730013, shape=(), dtype=float32)
# Время эпохи 33 в 11.872957468032837 секундах
# 34/50: ===========: tf.Tensor(5.8480425, shape=(), dtype=float32)
# Время эпохи 34 в 11.264798164367676 секундах
# 35/50: ===========: tf.Tensor(6.03075, shape=(), dtype=float32)
# Время эпохи 35 в 12.539806365966797 секундах
# 36/50: ===========: tf.Tensor(5.6279655, shape=(), dtype=float32)
# Время эпохи 36 в 12.230291366577148 секундах
# 37/50: ===========: tf.Tensor(5.4439077, shape=(), dtype=float32)
# Время эпохи 37 в 11.562206745147705 секундах
# 38/50: ===========: tf.Tensor(5.441043, shape=(), dtype=float32)
# Время эпохи 38 в 11.478240013122559 секундах
# 39/50: ===========: tf.Tensor(5.425362, shape=(), dtype=float32)
# Время эпохи 39 в 11.911064147949219 секундах
# 40/50: ===========: tf.Tensor(5.2876563, shape=(), dtype=float32)
# Время эпохи 40 в 11.862857818603516 секундах
# 41/50: ===========: tf.Tensor(5.0643725, shape=(), dtype=float32)
# Время эпохи 41 в 11.486160278320312 секундах
# 42/50: ===========: tf.Tensor(4.929774, shape=(), dtype=float32)
# Время эпохи 42 в 12.131530523300171 секундах
# 43/50: ===========: tf.Tensor(4.586356, shape=(), dtype=float32)
# Время эпохи 43 в 11.60534119606018 секундах
# 44/50: ===========: tf.Tensor(4.546248, shape=(), dtype=float32)
# Время эпохи 44 в 11.387952089309692 секундах
# 45/50: ===========: tf.Tensor(4.6081896, shape=(), dtype=float32)
# Время эпохи 45 в 12.008232831954956 секундах
# 46/50: ===========: tf.Tensor(4.564944, shape=(), dtype=float32)
# Время эпохи 46 в 11.33050012588501 секундах
# 47/50: ===========: tf.Tensor(4.207034, shape=(), dtype=float32)
# Время эпохи 47 в 11.137361764907837 секундах
# 48/50: ===========: tf.Tensor(4.215559, shape=(), dtype=float32)
# Время эпохи 48 в 11.291688203811646 секундах
# 49/50: ===========: tf.Tensor(4.1354375, shape=(), dtype=float32)
# Время эпохи 49 в 11.343448162078857 секундах
# 50/50: ===========: tf.Tensor(4.3105946, shape=(), dtype=float32)
# Время эпохи 50 в 11.128190040588379 секундах

# %%
# отображение результатов генерации
n = 2
total = 2*n+1

plt.figure(figsize=(total, total))

num = 1
for i in range(-n, n+1):
    for j in range(-n, n+1):
        ax = plt.subplot(total, total, num)
        num += 1
        img = decoder.predict(np.expand_dims([0.5*i/n, 0.5*j/n], axis=0))
        plt.imshow(img.squeeze(), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
